# %%
import pandas as pd

# %%
pd.DataFrame([1])
# Out:
#    0
# 0  1

# %%
import pandas as pd

# всякие магиеческие метды
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %env OMP_NUM_THREADS=72
# %config InlineBackend.figure_format ='retina'

pd.set_option('display.max_rows', 30)
pd.options.display.max_columns = None
pd.options.display.float_format = '{:,.3f}'.format

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# env: OMP_NUM_THREADS=72

# %%
from pathlib import Path

Path('.').absolute()
# Out:
# PosixPath('/Users/dimitrius/projects/personal/VRP/customer_cases/eapteka')

# %%
import os

coords = pd.read_excel('../../data/eapteka/data/update_3.xlsx')  # xlrd пока сломан в 3.9
orders = pd.read_excel('../../data/eapteka/data/Заказы_13.xlsx')

points = coords.join(orders)

stocks = pd.read_excel('../../data/eapteka/data/Склады.xlsx')

# %%
s_res = stocks['Наименование'].map(lambda s: s[4:].strip()).tolist()

# %%
res = unique_stocks = points['Склад'].unique()
p_res = pd.Series(unique_stocks).map(lambda s: s[4:].strip()).tolist()

# %%
set(p_res) - set(s_res)
# Out:
# set()

# %%
stocks[['Долгота', 'Широта']].values
# Out:
# array([[37.55867 , 55.7621  ],
#        [37.678837, 55.766116],
#        [37.750604, 55.699081],
#        [37.561509, 55.692475],
#        [37.545761, 55.863015],
#        [37.652616, 55.81174 ],
#        [37.605337, 55.807506],
#        [37.658634, 55.708511],
#        [37.436634, 55.862141],
#        [37.407438, 55.803484],
#        [37.797703, 55.811619]])

# %%
stocksoints

# вытаскиваем время из строки
time_regex = r"Доставка с ([0-9]{0,2}).* по ([0-9]{0,2}).*$"
times = df["ИнтервалДоставки"]
t_from = times.map(lambda x: regex.search(time_regex, x).group(1))
t_to = times.map(lambda x: regex.search(time_regex, x).group(2))

# фиксим отсутствующие
t_to[t_to == ""] = "24"
t_from[t_from == ""] = "00"

# фиксим типы данных
t_to = t_to.astype(int)
t_from = t_from.astype(int)

# фиксим окна с неправиьным временем
t_to[t_to <= t_from] = 24

#
df["t_from"] = t_from
df["t_to"] = t_to
df["priority"] = df["Приоритет"].map(lambda x: math.isfinite(x))

df["lat"] = df["lat"].astype(float)
df["lon"] = df["lng"].astype(float)

df["geozone"] = df["ЗонаДоставки"]

df["weight"] = df["ВесЗаказа"].fillna(0).astype(float)
df["volume"] = df["ОбъемЗаказа"].fillna(0).astype(float)
df["price"] = df["СуммаДокумента"].fillna(0).astype(float)

df["depot"] = df["Склад"]

df["name"] = df["corrected"]
df["id"] = df.index

df
# Out:
#         id                                                was  \
# 0        0          Москва, Королев г, Коминтерна улица, д.15
# 1        1                      Москва, Ангарская улица, 67к1
# 2        2  Москва, д.10, корп.1, п-д 6 (код 288к6666), эт...
# 3        3             Москва, улица Генерала Кузнецова, 28к1
# 4        4  Москва, д.28, корп.25, п-д 1 (код 137), эт.21,...
# ...    ...                                                ...
# 6610  6610  Москва, м.Перово                             ,...
# 6611  6611  Москва, м.Выхино                             ,...
# 6612  6612                       Москва, проезд Дежнёва, 29к1
# 6613  6613  Москва, м.Выхино                             ,...
# 2     Москва, д.10, корп.1, п-д 6 (код 288к6666), эт...       2,029.000
# 3                Москва, улица Генерала Кузнецова, 28к1          72.000
# 4     Москва, д.28, корп.25, п-д 1 (код 137), эт.21,...       1,569.000
# ...                                                 ...             ...
# 6610  Москва, м.Перово                             ,...       1,303.000
# 6611  Москва, м.Выхино                             ,...       1,120.000
# 6612                       Москва, проезд Дежнёва, 29к1         281.000
# 6613  Москва, м.Выхино                             ,...       1,120.000
# 6614                       Москва, проезд Дежнёва, 29к1         281.000
#
#       ВесЗаказа  ОбъемЗаказа  \
# 0           nan        0.140
# 1         0.972        8.084
# 2           nan        0.795
# 3         0.189        0.456
# 4           nan        0.671
# ...         ...          ...
# 6610        nan        0.050
# 6611        nan       16.600
# 6612      0.369        0.640
# 6613        nan       16.600
# 6614      0.369        0.640
#
#                                      КомментарийКлиента  Приоритет  \
# 0     ПЛАНЕТА ЗДОРОВЬЯ Королев, Коминтерна ул, 15, Ч...        nan
# 1                                                   NaN        nan
# 2     г. Москва, ул Кировоградская, д.10, корп.1, по...        nan
# 3                                                   NaN      1.000
# 4     г. Москва, ул Берзарина, д.28, корп.25, подъез...        nan
# ...                                                 ...        ...
# 6610  ПЛАНЕТА ЗДОРОВЬЯ Зеленый пр-т, 56, Часы работы...        nan
# 6611                                                NaN        nan
# 6612                                                NaN        nan
# 6613                                                NaN        nan
# 6614                                                NaN        nan
#
#       Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0             nan          nan          nan          nan          nan
# 1             nan          nan          nan          nan          nan
# 2             nan          nan          nan          nan          nan
# 3             nan          nan          nan          nan          nan
# 4             nan          nan          nan          nan          nan
# ...           ...          ...          ...          ...          ...
# 6610          nan          nan          nan          nan          nan
# 6611          nan          nan          nan          nan          nan
# 6612          nan          nan          nan          nan          nan
# 6613          nan          nan          nan          nan          nan
# 6614          nan          nan          nan          nan          nan
#
#       Unnamed: 16  t_from  t_to  priority    lon geozone  weight  volume  \
# 0             nan      12    14     False 37.814      Я1   0.000   0.140
# 1             nan       9    18     False 37.525      55   0.972   8.084
# 2             nan      15    21     False 37.607      45   0.000   0.795
# 3             nan       9    18      True 37.852      59   0.189   0.456
# 4             nan       6     9     False 37.475      51   0.000   0.671
# ...           ...     ...   ...       ...    ...     ...     ...     ...
# 6610          nan       9    15     False 37.802      22   0.000   0.050
# 6611          nan       9    15     False 37.834      22   0.000  16.600
# 6612          nan       9    18     False 37.631      56   0.369   0.640
# 6613          nan       9    15     False 37.834      22   0.000  16.600
# 6614          nan       9    18     False 37.631      56   0.369   0.640
#
#          price                    depot  \
# 0    4,900.000  Мск, Марьина роща склад
# 1    1,486.000  Мск, Марьина роща склад
# 2    2,029.000  Мск, Марьина роща склад
# 3       72.000  Мск, Марьина роща склад
# 4    1,569.000  Мск, Марьина роща склад
# ...        ...                      ...
# 6610 1,303.000  Мск, Марьина роща склад
# 6611 1,120.000  Мск, Марьина роща склад
# 6612   281.000  Мск, Марьина роща склад
# 6613 1,120.000  Мск, Марьина роща склад
# 4    37.475  10852600  13.09.2020 0:00:00  Мск, Марьина роща склад
# ...     ...       ...                 ...                      ...
# 6610 37.802  10851239  13.09.2020 0:00:00  Мск, Марьина роща склад
# 6611 37.834  10850523  13.09.2020 0:00:00  Мск, Марьина роща склад
# 6612 37.631   9128823  13.09.2020 0:00:00  Мск, Марьина роща склад
# 6613 37.834  10850523  13.09.2020 0:00:00  Мск, Марьина роща склад
# 6614 37.631   9128823  13.09.2020 0:00:00  Мск, Марьина роща склад
#
#      ЗонаДоставки           ИнтервалДоставки  \
# 0              Я1  Доставка с 12:00 по 14:00
# 1              55  Доставка с 09:00 по 18:00
# 2              45  Доставка с 15:00 по 21:00
# 3              59  Доставка с 09:00 по 18:00
# 4              51  Доставка с 06:00 по 09:00
# ...           ...                        ...
# 6610           22  Доставка с 09:00 по 15:00
# 6611           22  Доставка с 09:00 по 15:00
# 6612           56  Доставка с 09:00 по 18:00
# 6613           22  Доставка с 09:00 по 15:00
# 6614           56  Доставка с 09:00 по 18:00
#
#                                           АдресДоставки  СуммаДокумента  \
# 0             Москва, Королев г, Коминтерна улица, д.15       4,900.000
# 1                         Москва, Ангарская улица, 67к1       1,486.000
# 2     Москва, д.10, корп.1, п-д 6 (код 288к6666), эт...       2,029.000
# 3                Москва, улица Генерала Кузнецова, 28к1          72.000
# 4     Москва, д.28, корп.25, п-д 1 (код 137), эт.21,...       1,569.000
# ...                                                 ...             ...
# 6610  Москва, м.Перово                             ,...       1,303.000
# 6611  Москва, м.Выхино                             ,...       1,120.000
# 6612                       Москва, проезд Дежнёва, 29к1         281.000
# 6613  Москва, м.Выхино                             ,...       1,120.000
# 6614                       Москва, проезд Дежнёва, 29к1         281.000
#
#       ВесЗаказа  ОбъемЗаказа  \
# 0           nan        0.140
# 1         0.972        8.084
# 2           nan        0.795
# 3         0.189        0.456
# 4           nan        0.671
# ...         ...          ...
# 6610        nan        0.050
# 6611        nan       16.600
# 6612      0.369        0.640
# 6613        nan       16.600
# 6614      0.369        0.640
#
#                                      КомментарийКлиента  Приоритет  \
# 0     ПЛАНЕТА ЗДОРОВЬЯ Королев, Коминтерна ул, 15, Ч...        nan
# 1                                                   NaN        nan
# 2     г. Москва, ул Кировоградская, д.10, корп.1, по...        nan
# 3                                                   NaN      1.000
# 4     г. Москва, ул Берзарина, д.28, корп.25, подъез...        nan
# ...                                                 ...        ...
# 6610  ПЛАНЕТА ЗДОРОВЬЯ Зеленый пр-т, 56, Часы работы...        nan
# 6611                                                NaN        nan
# 6612                                                NaN        nan
# 6613                                                NaN        nan
# 6614                                                NaN        nan
#
#       Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0             nan          nan          nan          nan          nan
# 1             nan          nan          nan          nan          nan
# 2             nan          nan          nan          nan          nan
# 3             nan          nan          nan          nan          nan
# 4             nan          nan          nan          nan          nan
# ...           ...          ...          ...          ...          ...
# 6610          nan          nan          nan          nan          nan
# 6611          nan          nan          nan          nan          nan
# 6612          nan          nan          nan          nan          nan
# 6613          nan          nan          nan          nan          nan
# 6614          nan          nan          nan          nan          nan
#
#       Unnamed: 16
# 0             nan
# 1             nan
# 2             nan
# 3             nan
# 4             nan
# ...           ...
# 6610          nan
# 6611          nan
# 6612          nan
# 6613          nan
# 6614          nan
#
# [6615 rows x 24 columns]

# %%
points['ДатаДоставки'].unique()
# Out:
# array(['13.09.2020 0:00:00'], dtype=object)

# %%
import regex
import math 

time_regex = r'([0-9]{0,2})-([0-9]{0,2})$'
times = df['График работы'].replace('круглосуточно', '0-24')

df['t_from'] = times.map(lambda x: regex.search(time_regex, x).group(1)).astype('int')
df['t_to'] = times.map(lambda x: regex.search(time_regex, x).group(2)).astype('int')
df['lat'] = df['Широта'].astype('float')
df['lon'] = df['Долгота'].astype('float')
df['name'] = df['Наименование']

# df['Стоимость 1 заказа'] = df['Стоимость 1 заказа'].astype('int')
# df['profile'] = df['Должность'].map(lambda x: {"Курьер": "transport", "Водитель": "driver"}[x])
# df['name'] = df['Сотрудник']
# df['priority'] = df['Приоритет'].map(lambda x: math.isfinite(x))

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Наименование   11 non-null     object
#  1   Адрес          11 non-null     object
#  2   График работы  11 non-null     object
#  3   Широта         11 non-null     float64
#  4   Долгота        11 non-null     float64
#  5   t_from         11 non-null     int64
#  6   t_to           11 non-null     int64
#  7   name           11 non-null     object
#  8   lat            11 non-null     float64
#  9   lon            11 non-null     float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 1008.0+ bytes

# %%
df
# Out:
#    Интервал работы                       Сотрудник Должность  \
# 0            16-22       Акперов Ильгар Натиг Оглы    Курьер
# 1             9-21    Бердников Евгений Леонидович  Водитель
# 2            10-21      Богомолов Даниил Денисович  Водитель
# 3             9-14      Бортников Сергей Сергеевич    Курьер
# 4            18-22      Бортников Сергей Сергеевич    Курьер
# 5             9-20      Броновицкий Глеб Сергеевич  Водитель
# 6             9-21  Васильев Алексей Александрович    Курьер
# 7            16-24    Гилевский Игорь Владимирович    Курьер
# 8            10-21      Емельнов Сергей Николаевич  Водитель
# 9            10-19      Жилкина Оксана Григорьевна    Курьер
# 10           10-21        Зверев Сергей Николаевич    Курьер
# 11           16-24        Иванов Руслан Васильевич  Водитель
# 12           10-21     Калугин Кирилл Владимирович    Курьер
# 13           10-22    Комаров Владислав Алексеевич  Водитель
# 14            7-16  Комарчук Владимир Владимирович  Водитель
# 15           10-21           Комов Виктор Иванович  Водитель
# 16            9-21    Корнев Константин Витальевич  Водитель
# 17            9-21     Лашина Полина Александровна    Курьер
# 18           10-21      Линкевич Роман Анатольевич  Водитель
# 19           10-21       Луканкин Вадим Валерьевич    Курьер
# 20            9-21     Лукашенко Виктор Степанович    Курьер
# 21            9-22          Матвеев Максим Юрьевич    Курьер
# 22            9-21          Наумов Максим Иванович    Курьер
# 23            9-21        Немтинов Марк Михайлович  Водитель
# 24           10-21    Неронов Кирилл Александрович  Водитель
# 25            9-21      Несын Кирилл Александрович  Водитель
# 26            9-12       Пушкаш Евгений Николаевич    Курьер
# 27           18-24       Пушкаш Евгений Николаевич    Курьер
# 28            8-17  Расторгуев Олег Константинович    Курьер
# 29            7-14        Салимов Рустам Мобинович    Курьер
# 30           18-22        Салимов Рустам Мобинович    Курьер
# 31           10-21     Тутубалин Андрей Валерьевич    Курьер
# 32            9-21    Фетков Александр Геннадьевич    Курьер
# 33            9-21      Худин Андрей Александрович  Водитель
#
#     Стоимость 1 заказа  Приоритет  t_from  t_to    profile  \
# 0                    5        NaN      16    22  transport
# 1                   10        NaN       9    21     driver
# 2                   10        NaN      10    21     driver
# 3                    5        1.0       9    14  transport
# 4                    5        1.0      18    22  transport
# 5                   10        NaN       9    20     driver
# 6                    5        NaN       9    21  transport
# 7                    5        NaN      16    24  transport
# 8                   10        1.0      10    21     driver
# 9                    5        1.0      10    19  transport
# 10                   5        NaN      10    21  transport
# 11                  10        NaN      16    24     driver
# 12                   5        NaN      10    21  transport
# 13                  10        NaN      10    22     driver
# 14                  10        NaN       7    16     driver
# 15                  10        NaN      10    21     driver
# 16                  10        NaN       9    21     driver
# 17                   5        NaN       9    21  transport
# 18                  10        1.0      10    21     driver
# 19                   5        1.0      10    21  transport
# 20                   5        1.0       9    21  transport
# 21                   5        NaN       9    22  transport
# 22                   5        NaN       9    21  transport
# 23                  10        NaN       9    21     driver
# 24                  10        NaN      10    21     driver
# 25                  10        NaN       9    21     driver
# 26                   5        NaN       9    12  transport
# 27                   5        NaN      18    24  transport
# 28                   5        NaN       8    17  transport
# 29                   5        NaN       7    14  transport
# 30                   5        NaN      18    22  transport
# 31                   5        NaN      10    21  transport
# 32                   5        NaN       9    21  transport
# 33                  10        NaN       9    21     driver
#
#                               name  priority
# 0        Акперов Ильгар Натиг Оглы     False
# 1     Бердников Евгений Леонидович     False
# 2       Богомолов Даниил Денисович     False
# 3       Бортников Сергей Сергеевич      True
# 4       Бортников Сергей Сергеевич      True
# 5       Броновицкий Глеб Сергеевич     False
# 6   Васильев Алексей Александрович     False
# 7     Гилевский Игорь Владимирович     False
# 8       Емельнов Сергей Николаевич      True
# 9       Жилкина Оксана Григорьевна      True
# 10        Зверев Сергей Николаевич     False
# 11        Иванов Руслан Васильевич     False
# 12     Калугин Кирилл Владимирович     False
# 13    Комаров Владислав Алексеевич     False
# 14  Комарчук Владимир Владимирович     False
# 15           Комов Виктор Иванович     False
# 16    Корнев Константин Витальевич     False
# 17     Лашина Полина Александровна     False
# 18      Линкевич Роман Анатольевич      True
# 19       Луканкин Вадим Валерьевич      True
# 20     Лукашенко Виктор Степанович      True
# 21          Матвеев Максим Юрьевич     False
# 22          Наумов Максим Иванович     False
# 23        Немтинов Марк Михайлович     False
# 24    Неронов Кирилл Александрович     False
# 25      Несын Кирилл Александрович     False
# 26       Пушкаш Евгений Николаевич     False
# 27       Пушкаш Евгений Николаевич     False
# 28  Расторгуев Олег Константинович     False
# 29        Салимов Рустам Мобинович     False
# 30        Салимов Рустам Мобинович     False
# 31     Тутубалин Андрей Валерьевич     False
# 32    Фетков Александр Геннадьевич     False
# 33      Худин Андрей Александрович     False
